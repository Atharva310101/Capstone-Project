# %%
import matplotlib.pyplot as plt
import pandas as pd
import time

# Model performance summary
eval_data = {
    "Model": [
        "BERT (BoolQ)", "DistilBERT (BoolQ)", "RoBERTa (BoolQ)",
        "RoBERTa (BoolQ→PubMedQA)", "TAPT-6K", "TAPT-10K", "TAPT-15K"
    ],
    "Accuracy": [0.7153, 0.7073, 0.7835, 0.8442, 0.8483, 0.8983, 0.8792],
    "F1 Score": [0.7893, 0.7735, 0.8261, 0.9131, 0.9179, 0.9408, 0.9296]
}

df_eval = pd.DataFrame(eval_data)

# Bar plot for Accuracy
plt.figure(figsize=(10, 5))
plt.bar(df_eval["Model"], df_eval["Accuracy"], width=0.4)
plt.ylabel("Accuracy")
plt.title("Model Accuracy Comparison")
plt.xticks(rotation=25, ha='right')
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()
time.sleep(1)

# Bar plot for F1 Score
plt.figure(figsize=(10, 5))
plt.bar(df_eval["Model"], df_eval["F1 Score"], width=0.4, color='orange')
plt.ylabel("F1 Score")
plt.title("Model F1 Score Comparison")
plt.xticks(rotation=25, ha='right')
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()
time.sleep(1)

# Line plot: Training loss over epochs
epochs = [1, 2, 3]
loss_6k = [0.4190, 0.3899, 0.3723]
loss_10k = [0.3727, 0.3087, 0.2137]
loss_15k = [0.3897, 0.3246, 0.2427]

plt.figure(figsize=(6, 6))
plt.plot(epochs, loss_6k, marker='o', label="TAPT-6K")
plt.plot(epochs, loss_10k, marker='o', label="TAPT-10K")
plt.plot(epochs, loss_15k, marker='o', label="TAPT-15K")
plt.xticks(epochs)
plt.xlabel("Epoch")
plt.ylabel("Avg Train Loss")
plt.title("Training Loss over Epochs")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()
time.sleep(1)

# Line plot: Accuracy over epochs
acc_6k = [0.8483, 0.8108, 0.8375]
acc_10k = [0.8792, 0.8867, 0.8983]
acc_15k = [0.8483, 0.8600, 0.8792]

plt.figure(figsize=(6, 6))
plt.plot(epochs, acc_6k, marker='o', label="TAPT-6K")
plt.plot(epochs, acc_10k, marker='o', label="TAPT-10K")
plt.plot(epochs, acc_15k, marker='o', label="TAPT-15K")
plt.xticks(epochs)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Dev Accuracy over Epochs")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()
time.sleep(1)

# Line plot: F1 Score over epochs
f1_6k = [0.9179, 0.8907, 0.9088]
f1_10k = [0.9325, 0.9333, 0.9408]
f1_15k = [0.9178, 0.9162, 0.9296]

plt.figure(figsize=(6, 6))
plt.plot(epochs, f1_6k, marker='o', label="TAPT-6K")
plt.plot(epochs, f1_10k, marker='o', label="TAPT-10K")
plt.plot(epochs, f1_15k, marker='o', label="TAPT-15K")
plt.xticks(epochs)
plt.xlabel("Epoch")
plt.ylabel("F1 Score")
plt.title("Dev F1 Score over Epochs")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()

# %%
# Training loss over epochs for TAPT-6K, 10K, and 15K
epochs = [1, 2, 3]
loss_6k = [0.4190, 0.3899, 0.3723]
loss_10k = [0.3727, 0.3087, 0.2137]
loss_15k = [0.3897, 0.3246, 0.2427]

plt.figure(figsize=(10, 6))
plt.plot(epochs, loss_6k, marker='o', label="TAPT-6K")
plt.plot(epochs, loss_10k, marker='o', label="TAPT-10K")
plt.plot(epochs, loss_15k, marker='o', label="TAPT-15K")
plt.xticks(epochs)
plt.xlabel("Epoch")
plt.ylabel("Avg Train Loss")
plt.title("Training Loss over Epochs (TAPT)")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()

# Accuracy over epochs
acc_6k = [0.8483, 0.8108, 0.8375]
acc_10k = [0.8792, 0.8867, 0.8983]
acc_15k = [0.8483, 0.8600, 0.8792]

plt.figure(figsize=(10, 6))
plt.plot(epochs, acc_6k, marker='o', label="TAPT-6K")
plt.plot(epochs, acc_10k, marker='o', label="TAPT-10K")
plt.plot(epochs, acc_15k, marker='o', label="TAPT-15K")
plt.xticks(epochs)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Validation Accuracy over Epochs (TAPT)")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()

# F1 Score over epochs
f1_6k = [0.9179, 0.8907, 0.9088]
f1_10k = [0.9325, 0.9333, 0.9408]
f1_15k = [0.9178, 0.9162, 0.9296]

plt.figure(figsize=(10, 6))
plt.plot(epochs, f1_6k, marker='o', label="TAPT-6K")
plt.plot(epochs, f1_10k, marker='o', label="TAPT-10K")
plt.plot(epochs, f1_15k, marker='o', label="TAPT-15K")
plt.xticks(epochs)
plt.xlabel("Epoch")
plt.ylabel("F1 Score")
plt.title("Validation F1 Score over Epochs (TAPT)")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Step-wise training losses
steps_6k = list(range(100, 2251, 100))
losses_6k = [
    6.3812, 3.6775, 2.7830, 2.4235, 2.2544, 2.1279, 2.0270, 1.9182, 1.9079, 1.8507,
    1.7942, 1.7591, 1.7646, 1.7282, 1.7012, 1.6880, 1.6383, 1.5816, 1.6308, 1.5899,
    1.5935, 1.5696
]

steps_10k = list(range(100, 3801, 100))
losses_10k = [
    6.4613, 3.8220, 2.9461, 2.4642, 2.2912, 2.1631, 2.0252, 2.0096, 1.9234, 1.8926,
    1.8244, 1.8001, 1.7772, 1.7329, 1.6760, 1.6519, 1.6375, 1.6256, 1.6366, 1.6037,
    1.6445, 1.6003, 1.6120, 1.5440, 1.5766, 1.5248, 1.5443, 1.5570, 1.5030, 1.4993,
    1.4758, 1.4932, 1.4761, 1.4575, 1.4769, 1.4520, 1.4804
]

steps_15k = list(range(100, 5700, 100))
losses_15k = [
    1.4196, 1.4062, 1.3769, 1.3941, 1.3829, 1.3868, 1.3908, 1.3591, 1.3304, 1.3490,
    1.3533, 1.3471, 1.3334, 1.3251, 1.3150, 1.3271, 1.3266, 1.2965, 1.3006, 1.2908,
    1.2639, 1.2361, 1.2767, 1.2579, 1.2684, 1.2431, 1.2234, 1.2452, 1.2248, 1.2403,
    1.2392, 1.2136, 1.2150, 1.2327, 1.2028, 1.2003, 1.2086, 1.2068, 1.1924, 1.1739,
    1.1594, 1.1812, 1.1739, 1.1760, 1.1633, 1.1505, 1.1429, 1.1427, 1.1476, 1.1396,
    1.1634, 1.1790, 1.1372, 1.1591, 1.1502, 1.1397
]
# Ensure matching lengths
min_len_10k = min(len(steps_10k), len(losses_10k))
steps_10k = steps_10k[:min_len_10k]
losses_10k = losses_10k[:min_len_10k]

min_len_15k = min(len(steps_15k), len(losses_15k))
steps_15k = steps_15k[:min_len_15k]
losses_15k = losses_15k[:min_len_15k]


# Plotting step-wise training loss for all TAPT models
plt.figure(figsize=(8, 8))
plt.plot(steps_6k, losses_6k, label="TAPT-6K")
plt.plot(steps_10k, losses_10k, label="TAPT-10K")
plt.plot(steps_15k, losses_15k, label="TAPT-15K")
plt.xlabel("Training Steps")
plt.ylabel("Training Loss")
plt.title("Step-wise Training Loss Curves for TAPT Models")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 4))
sns.heatmap(df_eval.set_index("Model"), annot=True, cmap="YlGnBu", fmt=".4f", cbar=True)
plt.title("Model Evaluation Metrics Heatmap")
plt.tight_layout()
plt.show()
